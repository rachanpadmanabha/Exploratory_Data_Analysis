# %% [markdown]
# # 1.List all the cities and the respective number of pending orders in 'India'?

# %%
import pandas as pd

# %%
df = pd.read_csv('DataCoSupplyChainDataset.csv',engine='python')

# %%
    df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
updated_df =df.drop(columns =['Product Description'])

# %%
updated_df.info()
#removed the columns with null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180519 entries, 0 to 180518
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180519 non-null  object
#  1   Days for shipping (real)       180519 non-null  int64
#  2   Days for shipment (scheduled)  180519 non-null  int64
#  3   Benefit per order              180519 non-null  float64
#  4   Sales per customer             180519 non-null  float64
#  5   Delivery Status                180519 non-null  object
#  6   Late_delivery_risk             180519 non-null  int64
#  7   Category Id                    180519 non-null  int64
#  8   Category Name                  180519 non-null  object
#  9   Customer City                  180519 non-null  object
#  10  Customer Country               180519 non-null  object
#  11  Customer Email                 180519 non-null  object
# ...

# %%
updated_df.shape
# Out:
# (180519, 52)

# %%
duplicate_rows = updated_df[updated_df.duplicated()]
print('number of duplicate rows',duplicate_rows.shape)
#trying to find any duplicate rows if present
# Out:
# number of duplicate rows (0, 52)

# %% [markdown]
# No Duplicate rows were found

# %%
print(updated_df["Order Status"].unique())
# Out:
# ['COMPLETE' 'PENDING' 'CLOSED' 'PENDING_PAYMENT' 'CANCELED' 'PROCESSING'
#  'SUSPECTED_FRAUD' 'ON_HOLD' 'PAYMENT_REVIEW']

# %%
pending_dataframe = df[df['Order Status'] == 'PENDING']

# %%
pending_dataframe
#the dataframe where all the orders are pending
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 11      TRANSFER                         5                              2
# 12      TRANSFER                         4                              2
# 21      TRANSFER                         5                              4
# 22      TRANSFER                         4                              2
# ...          ...                       ...                            ...
# 180414  TRANSFER                         0                              0
# 180458  TRANSFER                         4                              4
# 180485  TRANSFER                         4                              4
# 180491  TRANSFER                         3                              4
# 180516  TRANSFER                         5                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
pending_indian_dataframe = pending_dataframe[pending_dataframe['Order Country'] == 'India']
type(pending_dataframe['Order Country'] == 'India')
# Out:
# pandas.core.series.Series

# %%
pending_indian_dataframe
# this dataframe conrtains all the pending orders in India
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 1       TRANSFER                         5                              4
# 21      TRANSFER                         5                              4
# 45      TRANSFER                         6                              4
# 46      TRANSFER                         5                              2
# 382     TRANSFER                         3                              4
# ...          ...                       ...                            ...
# 180142  TRANSFER                         4                              4
# 180164  TRANSFER                         2                              1
# 180248  TRANSFER                         5                              2
# 180331  TRANSFER                         3                              4
# 180405  TRANSFER                         2                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
print(pending_indian_dataframe["Order City"].unique())
# Out:
# ['Bikaner' 'Jabalpur' 'Bangalore' 'Pune' 'Jaipur' 'Ranchi' 'Durg' 'Patna'
#  'Faridabad' 'Fatehpur' 'Kota' 'Guwahati' 'Rohtak' 'Mumbai' 'Kulti'
#  'Imphal' 'Gorakhpur' 'Lucknow' 'Hubli' 'Nagpur' 'Ajmer' 'Amravati'
#  'Raipur' 'Thane' 'Dewas' 'Tirunelveli' 'Darbhanga' 'Aligarh' 'Saharanpur'
#  'Vadodara' 'Delhi' 'Bhopal' 'Jodhpur' 'Kanpur' 'Moradabad' 'Belgaum'
#  'Hyderabad' 'Nellore' 'Korba' 'Jamnagar' 'Puducherry' 'Srinagar' 'Satna'
#  'Muzaffarpur' 'Pimpri' 'Bokaro' 'Ludhiana' 'Jhansi' 'Amritsar' 'Malegaon'
#  'Nasik' 'Coimbatore' 'Agra' 'Durgapur' 'Chennai' 'Gulbarga' 'Brahmapur'
#  'Thiruvananthapuram' 'Bhavnagar' 'Ujjain' 'Surat' 'Ganganagar'
#  'Visakhapatnam' 'Solapur' 'Salem' 'Meerut' 'Patiala' 'Rajkot' 'Warangal'
#  'Kollam' 'Hisar' 'Mangalore' 'Aurangabad' 'Bhubaneswar' 'Bilaspur'
#  'Kamarhati' 'Ulhasnagar' 'Shimoga' 'Parbhani' 'Mysore' 'Bhiwandi'
#  'Bellary' 'Anantapur' 'Bihar Sharif' 'Ghaziabad' 'Madurai' 'Ichalkaranji'
#  'Tiruppur' 'Kolhapur' 'Chandigarh' 'Jammu']

# %%
a = pending_indian_dataframe[pending_indian_dataframe['Order City'].value_counts()]

# %%
type(a)
a
# Out:
# Kanpur        25
# Pune          24
# Bangalore     24
# Lucknow       21
# Mumbai        18
#               ..
# Patiala        1
# Aurangabad     1
# Ghaziabad      1
# Hubli          1
# Jamnagar       1
# Name: Order City, Length: 91, dtype: int64

# %%
print(a.head(50))
print(a.tail(50))
#all the cities in India with the number of pending orders
# Out:
# Kanpur           25
# Pune             24
# Bangalore        24
# Lucknow          21
# Mumbai           18
# Delhi            18
# Hyderabad        17
# Ajmer            17
# Visakhapatnam    15
# Korba            14
# Nagpur           13
# Chennai          12
# Gorakhpur        12
# Jabalpur         11
# Durgapur         11
# Faridabad        10
# Darbhanga         9
# Jaipur            9
# Raipur            8
# Guwahati          8
# Kulti             8
# Belgaum           8
# Surat             7
# Salem             7
# Patna             7
# Kota              7
# Agra              7
# Jodhpur           7
# Bellary           6
# Bhubaneswar       6
# Nasik             6
# Amritsar          6
# Dewas             6
# Ujjain            5
# Imphal            5
# Coimbatore        5
# Moradabad         5
# Tirunelveli       5
# Ranchi            5
# Bokaro            5
# Ulhasnagar        5
# Rohtak            5
# Satna             5
# Jhansi            4
# Durg              4
# ...

# %% [markdown]
# # Ans. The above given cities of India are having pending orders(numbers given)

# %% [markdown]
# # 2. In this part we will be trying to find the Country with the most Suspected Fraud.

# %%
fraud_dataframe = df[df['Order Status'] == 'SUSPECTED_FRAUD']

# %%
fraud_dataframe
#this dataframe contains all the orders having Suspected_Fraud as its status.
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 10      TRANSFER                         6                              2
# 24      TRANSFER                         2                              2
# 183     TRANSFER                         5                              4
# 184     TRANSFER                         5                              4
# 185     TRANSFER                         6                              4
# ...          ...                       ...                            ...
# 180274  TRANSFER                         5                              2
# 180309  TRANSFER                         2                              1
# 180352  TRANSFER                         4                              4
# 180406  TRANSFER                         6                              4
# 180490  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer    Delivery Status  \
# ...

# %%
fraud_dataframe['Order Country'].value_counts()
# Out:
# Estados Unidos    573
# Francia           362
# México            317
# Alemania          227
# Australia         197
#                  ...
# Bangladés           1
# Somalia             1
# Benín               1
# Uzbekistán          1
# Georgia             1
# Name: Order Country, Length: 102, dtype: int64

# %% [markdown]
# # Ans. From the above cell's output we can see that "Estados Unidos" has the most suspected fraud in order status than other countries.

# %% [markdown]
# # 3. Which product(s) has/have the maximum discount?

# %%
print(updated_df["Product Name"].unique())
# Out:
# ['Smart watch ' 'Perfect Fitness Perfect Rip Deck'
#  "Under Armour Girls' Toddler Spine Surge Runni"
#  "Nike Men's Dri-FIT Victory Golf Polo"
#  "Under Armour Men's Compression EV SL Slide"
#  "Under Armour Women's Micro G Skulpt Running S"
#  "Nike Men's Free 5.0+ Running Shoe"
#  "Glove It Women's Mod Oval 3-Zip Carry All Gol"
#  'Bridgestone e6 Straight Distance NFL San Dieg'
#  "Columbia Men's PFG Anchor Tough T-Shirt" 'Titleist Pro V1x Golf Balls'
#  'Bridgestone e6 Straight Distance NFL Tennesse'
#  'Polar FT4 Heart Rate Monitor' 'ENO Atlas Hammock Straps'
#  "adidas Men's F10 Messi TRX FG Soccer Cleat"
#  "Brooks Women's Ghost 6 Running Shoe"
#  "Nike Men's CJ Elite 2 TD Football Cleat"
#  "Diamondback Women's Serene Classic Comfort Bi"
#  'Industrial consumer electronics' 'Web Camera' 'Dell Laptop'
#  'SOLE E25 Elliptical' 'Elevation Training Mask 2.0'
#  "adidas Men's Germany Black Crest Away Tee"
#  'Team Golf Pittsburgh Steelers Putter Grip'
# ...

# %%
print(updated_df["Order Item Discount"].unique())
# Out:
# [ 13.10999966  16.38999939  18.03000069 ... 140.          33.65999985
#   61.18999863]

# %%
discount_column = updated_df["Order Item Discount"]
max_value = discount_column.max()
print(max_value)
# Out:
# 500.0

# %%
max_discount_dataframe = updated_df[updated_df['Order Item Discount'] == 500.0]

# %%
max_discount_dataframe
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 12606  DEBIT                         4                              4
#
#        Benefit per order  Sales per customer   Delivery Status  \
# 12606               45.0          1499.98999  Shipping on time
#
#        Late_delivery_risk  Category Id      Category Name Customer City  ...  \
# 12606                   0           10  Strength Training        Caguas  ...
#
#       Order Status Order Zipcode Product Card Id  Product Category Id  \
# 12606     COMPLETE           NaN             208                   10
#
#                                            Product Image         Product Name  \
# 12606  http://images.acmesports.sports/SOLE+E35+Ellip...  SOLE E35 Elliptical
#
#       Product Price Product Status shipping date (DateOrders)   Shipping Mode
# 12606    1999.98999              0            10/3/2017 21:22  Standard Class
#
# [1 rows x 52 columns]

# %%
print(updated_df.loc[updated_df['Order Item Discount'] == 500.0])
# Out:
#         Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 12606  DEBIT                         4                              4
#
#        Benefit per order  Sales per customer   Delivery Status  \
# 12606               45.0          1499.98999  Shipping on time
#
#        Late_delivery_risk  Category Id      Category Name Customer City  ...  \
# 12606                   0           10  Strength Training        Caguas  ...
#
#       Order Status Order Zipcode Product Card Id  Product Category Id  \
# 12606     COMPLETE           NaN             208                   10
#
#                                            Product Image         Product Name  \
# 12606  http://images.acmesports.sports/SOLE+E35+Ellip...  SOLE E35 Elliptical
#
#       Product Price Product Status shipping date (DateOrders)   Shipping Mode
# 12606    1999.98999              0            10/3/2017 21:22  Standard Class
#
# [1 rows x 52 columns]

# %%
print(max_discount_dataframe['Product Name'].head())
#this gives us the name of product(s) which has/have the maximum discount
# Out:
# 12606    SOLE E35 Elliptical
# Name: Product Name, dtype: object

# %% [markdown]
# # Ans. The product with name SOLE E35 Elliptical has maximum discount.

# %% [markdown]
# # 5. In this part we will find the How many successfully processed orders have days for shipping real (Real) > Days for shipment (Scheduled)?

# %%
Completed_order_dataframe = updated_df[updated_df['Order Status'] == 'COMPLETE']

# %%
Completed_order_dataframe
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0       DEBIT                         3                              4
# 3       DEBIT                         3                              4
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# ...       ...                       ...                            ...
# 180500  DEBIT                         3                              4
# 180505  DEBIT                         2                              4
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
Schedules = Completed_order_dataframe[Completed_order_dataframe["Days for shipping (real)"] > Completed_order_dataframe["Days for shipment (scheduled)"]]

# %%
Schedules
#this gives us a datframe with the days for shipping real (Real) > Days for shipment (Scheduled) condition.
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# 18      DEBIT                         2                              1
# 25      DEBIT                         6                              2
# ...       ...                       ...                            ...
# 180479  DEBIT                         6                              4
# 180499  DEBIT                         4                              2
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer Delivery Status  \
# ...

# %%
Schedules.shape
# Out:
# (34199, 52)

# %% [markdown]
# # ans. From the above output we see that there are 34199 orders that have days for shipping real (Real) > Days for shipment (Scheduled).

# %% [markdown]
# # 4. Which year had the minimum sales for "Nike" products?

# %%
nike_dataframe = updated_df.loc[updated_df['Product Name'].str.contains("nike", case=False)]

# %%
nike_dataframe
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 50       PAYMENT                         6                              2
# 52       PAYMENT                         3                              2
# 53       PAYMENT                         5                              2
# 54       PAYMENT                         6                              2
# 59       PAYMENT                         2                              2
# ...          ...                       ...                            ...
# 179604  TRANSFER                         5                              4
# 179605  TRANSFER                         2                              4
# 179606  TRANSFER                         3                              4
# 179607  TRANSFER                         5                              4
# 179608  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
nike2015_dataframe = updated_df.loc[updated_df['shipping date (DateOrders)'].str.contains("2015", case=False)]
sales_per_cust_column = nike2015_dataframe["Order Item Discount"]
sum_value2015 = sales_per_cust_column.sum()

# %%
sum_value2015
#the sales in year 2015
# Out:
# 1238527.2911785059

# %%
nike2016_dataframe = updated_df.loc[updated_df['shipping date (DateOrders)'].str.contains("2016", case=False)]
sales_per_cust_column = nike2016_dataframe["Order Item Discount"]
sum_value2016 = sales_per_cust_column.sum()

# %%
sum_value2016
#the sales in year 2016
# Out:
# 1247833.721141224

# %%
nike2017_dataframe = updated_df.loc[updated_df['shipping date (DateOrders)'].str.contains("2017", case=False)]
sales_per_cust_column = nike2017_dataframe["Order Item Discount"]
sum_value2017 = sales_per_cust_column.sum()

# %%
sum_value2017
#the sales in year 2017
# Out:
# 1202255.410429992

# %%
nike2018_dataframe = updated_df.loc[updated_df['shipping date (DateOrders)'].str.contains("2018", case=False)]
sales_per_cust_column = nike2018_dataframe["Order Item Discount"]
sum_value2018 = sales_per_cust_column.sum()

# %%
sum_value2018
#the sales in year 2018
# Out:
# 41761.979842847

# %%
#as we can see from the above values nike had minimum sales in 2018

# %% [markdown]
# # Nike products had minimum sales in the year 2018
